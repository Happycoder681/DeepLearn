# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17413, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17413 (delta 64), reused 22 (delta 22), pack-reused 17327 (from 4)
# Receiving objects: 100% (17413/17413), 16.30 MiB | 21.13 MiB/s, done.
# Resolving deltas: 100% (11935/11935), done.

# %%
# %cd yolov5/
# Out:
# /content/yolov5/yolov5

# %%
# !pip install -U -r requirements.txt

# %%
# !python detect.py --source "/content/yolov5/data/images/zidane.jpg" --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/yolov5/data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.7.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 141MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 1 tie, 32.1ms
# Speed: 0.5ms pre-process, 32.1ms inference, 141.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov5s.pt data="/content/drive/MyDrive/data/data.yaml" epochs=50 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.7.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
f=open('/root/.config/Ultralytics/settings.json','r')
print("".join(f.readlines()))
f.close()
# Out:
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/yolov5/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true
# }

# %%
import cv2
model=YOLO('/content/yolov5/yolov5/runs/detect/train7/weights/best.pt')
results=model('/content/yolov5/yolov5/runs/detect/exp3/zidane.jpg',show=True)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/yolov5/yolov5/runs/detect/exp3/zidane.jpg: 384x640 2 dogs, 4 cats, 44.7ms
# Speed: 2.2ms preprocess, 44.7ms inference, 160.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'dog', 1: 'cat'}
#  obb: None
#  orig_img: array([[[36, 48, 72],
#          [38, 50, 74],
#          [41, 52, 74],
#          ...,
#          [26, 22, 57],
#          [21, 19, 55],
#          [17, 15, 51]],
#
#         [[35, 47, 71],
#          [35, 47, 71],
#          [37, 48, 70],
#          ...,
#          [24, 20, 55],
#          [18, 16, 52],
#          [13, 11, 47]],
#
#         [[39, 51, 75],
#          [37, 49, 73],
#          [37, 48, 70],
#          ...,
#          [24, 20, 56],
#          [20, 16, 52],
#          [16, 12, 48]],
#
#         ...,
#
#         [[48, 43, 40],
#          [49, 44, 41],
#          [48, 43, 40],
#          ...,
#          [48, 48, 34],
#          [49, 49, 35],
#          [50, 50, 36]],
#
#         [[49, 42, 39],
#          [50, 43, 40],
#          [49, 42, 39],
#          ...,
# ...
